# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/val_dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %%
# Set random seed for reproducibility
tf.random.set_seed(42)

# %%
# Define constants
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 100
NUM_CLASSES = 5

# %%
# Define data directories
train_dir = '/content/train'
val_dir = '/content/val'
test_dir = '/content/test'

# %%
# Create data generators with augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 2820 images belonging to 5 classes.
# Found 355 images belonging to 5 classes.
# Found 350 images belonging to 5 classes.

# %%
# Load pre-trained VGG19 model
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step

# %%
# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# %%
# Add custom layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.3)(x)
outputs = Dense(NUM_CLASSES, activation='softmax')(x)

# %%
# Create the final model
model = Model(inputs=base_model.input, outputs=outputs)

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Define callbacks
early_stopping = EarlyStopping(patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(factor=0.2, patience=5, min_lr=1e-6)
#model_checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True)
model_checkpoint = ModelCheckpoint('best_model.keras', save_best_only=True)

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    validation_data=val_generator,
    validation_steps=val_generator.samples // BATCH_SIZE,
    epochs=EPOCHS,
    callbacks=[early_stopping, reduce_lr, model_checkpoint]
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 63s 511ms/step - accuracy: 0.2009 - loss: 1.7114 - val_accuracy: 0.2102 - val_loss: 1.6084 - learning_rate: 1.0000e-04
# Epoch 2/100
#  1/88 ━━━━━━━━━━━━━━━━━━━━ 11s 136ms/step - accuracy: 0.3125 - loss: 1.6320
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.3125 - loss: 1.6320 - val_accuracy: 0.0000e+00 - val_loss: 1.6335 - learning_rate: 1.0000e-04
# Epoch 3/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 60s 445ms/step - accuracy: 0.2202 - loss: 1.6519 - val_accuracy: 0.2443 - val_loss: 1.6115 - learning_rate: 1.0000e-04
# Epoch 4/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.0938 - loss: 1.7055 - val_accuracy: 0.3333 - val_loss: 1.5260 - learning_rate: 1.0000e-04
# Epoch 5/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 81s 453ms/step - accuracy: 0.2067 - loss: 1.6358 - val_accuracy: 0.2159 - val_loss: 1.6031 - learning_rate: 1.0000e-04
# Epoch 6/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - accuracy: 0.0625 - loss: 1.7307 - val_accuracy: 0.0000e+00 - val_loss: 1.6541 - learning_rate: 1.0000e-04
# Epoch 7/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 82s 452ms/step - accuracy: 0.2105 - loss: 1.6251 - val_accuracy: 0.2017 - val_loss: 1.6029 - learning_rate: 1.0000e-04
# Epoch 8/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.0938 - loss: 1.7096 - val_accuracy: 0.3333 - val_loss: 1.6191 - learning_rate: 1.0000e-04
# Epoch 9/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 42s 445ms/step - accuracy: 0.2222 - loss: 1.6199 - val_accuracy: 0.2443 - val_loss: 1.6007 - learning_rate: 1.0000e-04
# Epoch 10/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - accuracy: 0.1562 - loss: 1.6499 - val_accuracy: 0.3333 - val_loss: 1.6227 - learning_rate: 2.0000e-05
# Epoch 11/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 82s 448ms/step - accuracy: 0.2221 - loss: 1.6128 - val_accuracy: 0.2358 - val_loss: 1.6006 - learning_rate: 2.0000e-05
# Epoch 12/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - accuracy: 0.4062 - loss: 1.5884 - val_accuracy: 0.0000e+00 - val_loss: 1.5648 - learning_rate: 2.0000e-05
# Epoch 13/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 81s 435ms/step - accuracy: 0.2249 - loss: 1.6141 - val_accuracy: 0.2330 - val_loss: 1.5996 - learning_rate: 2.0000e-05
# Epoch 14/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - accuracy: 0.2812 - loss: 1.5717 - val_accuracy: 0.3333 - val_loss: 1.5633 - learning_rate: 2.0000e-05

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'],color='red',label='train')
plt.plot(history.history['val_accuracy'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'],color='red',label='train')
plt.plot(history.history['val_loss'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test accuracy: {test_accuracy:.4f}")
print(f"Test loss: {test_loss:.4f}")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.3877 - loss: 1.5701
# Test accuracy: 0.2543
# Test loss: 1.6095

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have your model and test_generator already defined

# Generate predictions
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)

# Get true labels
y_true = test_generator.classes

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# Print classification report
class_names = list(test_generator.class_indices.keys())
print(classification_report(y_true, y_pred_classes, target_names=class_names))

# If you want to save the confusion matrix plot
plt.savefig('confusion_matrix.png')
print("Confusion matrix saved as 'confusion_matrix.png'")

# If you want to save the classification report to a file
with open('classification_report.txt', 'w') as f:
    f.write(classification_report(y_true, y_pred_classes, target_names=class_names))
print("Classification report saved as 'classification_report.txt'")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 296ms/step
#                 precision    recall  f1-score   support
#
#           Mild       0.22      0.56      0.32        70
#       Moderate       0.28      0.39      0.33        70
#          No_DR       0.47      0.13      0.20        70
# Proliferate_DR       0.00      0.00      0.00        70
#         Severe       0.24      0.20      0.22        70
#
#       accuracy                           0.25       350
#      macro avg       0.24      0.25      0.21       350
#   weighted avg       0.24      0.25      0.21       350
#
# Confusion matrix saved as 'confusion_matrix.png'
# Classification report saved as 'classification_report.txt'

# %%
# Fine-tuning: Unfreeze some layers of the base model
for layer in base_model.layers[-4:]:
    layer.trainable = True

# %%
# Recompile the model with a lower learning rate
model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model again (fine-tuning)
history_fine = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    validation_data=val_generator,
    validation_steps=val_generator.samples // BATCH_SIZE,
    epochs=50,
    callbacks=[early_stopping, reduce_lr, model_checkpoint]
)
# Out:
# Epoch 1/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 68s 513ms/step - accuracy: 0.2059 - loss: 1.6304 - val_accuracy: 0.2102 - val_loss: 1.6028 - learning_rate: 1.0000e-05
# Epoch 2/50
#  1/88 ━━━━━━━━━━━━━━━━━━━━ 15s 174ms/step - accuracy: 0.2812 - loss: 1.6407
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2812 - loss: 1.6407 - val_accuracy: 0.6667 - val_loss: 1.5367 - learning_rate: 1.0000e-05
# Epoch 3/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 65s 470ms/step - accuracy: 0.2100 - loss: 1.6324 - val_accuracy: 0.2102 - val_loss: 1.6027 - learning_rate: 1.0000e-05
# Epoch 4/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - accuracy: 0.3125 - loss: 1.5787 - val_accuracy: 0.0000e+00 - val_loss: 1.6535 - learning_rate: 1.0000e-05
# Epoch 5/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 44s 467ms/step - accuracy: 0.2186 - loss: 1.6130 - val_accuracy: 0.2557 - val_loss: 1.5888 - learning_rate: 1.0000e-05
# Epoch 6/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3125 - loss: 1.5127 - val_accuracy: 0.3333 - val_loss: 1.4830 - learning_rate: 1.0000e-05
# Epoch 7/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 81s 467ms/step - accuracy: 0.2334 - loss: 1.5979 - val_accuracy: 0.2614 - val_loss: 1.5838 - learning_rate: 1.0000e-05
# Epoch 8/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2812 - loss: 1.5910 - val_accuracy: 0.3333 - val_loss: 1.5670 - learning_rate: 1.0000e-05
# Epoch 9/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 44s 469ms/step - accuracy: 0.2553 - loss: 1.5866 - val_accuracy: 0.2642 - val_loss: 1.5903 - learning_rate: 1.0000e-05
# Epoch 10/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - accuracy: 0.1562 - loss: 1.6140 - val_accuracy: 0.3333 - val_loss: 1.5379 - learning_rate: 1.0000e-05
# Epoch 11/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 44s 466ms/step - accuracy: 0.2810 - loss: 1.5666 - val_accuracy: 0.2670 - val_loss: 1.5790 - learning_rate: 1.0000e-05
# Epoch 12/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - accuracy: 0.2812 - loss: 1.5790 - val_accuracy: 0.6667 - val_loss: 1.3815 - learning_rate: 2.0000e-06
# Epoch 13/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 76s 459ms/step - accuracy: 0.2650 - loss: 1.5682 - val_accuracy: 0.2756 - val_loss: 1.5849 - learning_rate: 2.0000e-06
# Epoch 14/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - accuracy: 0.2188 - loss: 1.5364 - val_accuracy: 0.0000e+00 - val_loss: 1.5252 - learning_rate: 2.0000e-06
# Epoch 15/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 44s 471ms/step - accuracy: 0.2821 - loss: 1.5498 - val_accuracy: 0.2756 - val_loss: 1.5787 - learning_rate: 2.0000e-06
# Epoch 16/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - accuracy: 0.2812 - loss: 1.6152 - val_accuracy: 0.0000e+00 - val_loss: 1.5475 - learning_rate: 2.0000e-06
# Epoch 17/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 81s 461ms/step - accuracy: 0.2859 - loss: 1.5552 - val_accuracy: 0.2699 - val_loss: 1.5854 - learning_rate: 2.0000e-06
# Epoch 18/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2812 - loss: 1.5792 - val_accuracy: 0.0000e+00 - val_loss: 1.5298 - learning_rate: 1.0000e-06
# Epoch 19/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 81s 465ms/step - accuracy: 0.2985 - loss: 1.5486 - val_accuracy: 0.2699 - val_loss: 1.5820 - learning_rate: 1.0000e-06
# Epoch 20/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - accuracy: 0.3750 - loss: 1.4416 - val_accuracy: 0.0000e+00 - val_loss: 1.6345 - learning_rate: 1.0000e-06
# Epoch 21/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 82s 453ms/step - accuracy: 0.2758 - loss: 1.5539 - val_accuracy: 0.2756 - val_loss: 1.5819 - learning_rate: 1.0000e-06
# Epoch 22/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.1562 - loss: 1.5853 - val_accuracy: 0.3333 - val_loss: 1.3349 - learning_rate: 1.0000e-06
# Epoch 23/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 77s 470ms/step - accuracy: 0.2743 - loss: 1.5607 - val_accuracy: 0.2812 - val_loss: 1.5852 - learning_rate: 1.0000e-06
# Epoch 24/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - accuracy: 0.1562 - loss: 1.6468 - val_accuracy: 0.6667 - val_loss: 1.3885 - learning_rate: 1.0000e-06
# Epoch 25/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 462ms/step - accuracy: 0.2842 - loss: 1.5447 - val_accuracy: 0.2784 - val_loss: 1.5794 - learning_rate: 1.0000e-06
# Epoch 26/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - accuracy: 0.1562 - loss: 1.6167 - val_accuracy: 0.0000e+00 - val_loss: 1.8831 - learning_rate: 1.0000e-06
# Epoch 27/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 82s 464ms/step - accuracy: 0.2797 - loss: 1.5484 - val_accuracy: 0.2812 - val_loss: 1.5789 - learning_rate: 1.0000e-06
# Epoch 28/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - accuracy: 0.2812 - loss: 1.5519 - val_accuracy: 0.3333 - val_loss: 1.4223 - learning_rate: 1.0000e-06
# Epoch 29/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 43s 462ms/step - accuracy: 0.2701 - loss: 1.5605 - val_accuracy: 0.2812 - val_loss: 1.5813 - learning_rate: 1.0000e-06
# Epoch 30/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - accuracy: 0.1562 - loss: 1.6429 - val_accuracy: 0.6667 - val_loss: 1.4174 - learning_rate: 1.0000e-06
# Epoch 31/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 82s 464ms/step - accuracy: 0.2794 - loss: 1.5502 - val_accuracy: 0.2841 - val_loss: 1.5819 - learning_rate: 1.0000e-06
# Epoch 32/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - accuracy: 0.3125 - loss: 1.5272 - val_accuracy: 0.3333 - val_loss: 1.3931 - learning_rate: 1.0000e-06

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'],color='red',label='train')
plt.plot(history.history['val_accuracy'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'],color='red',label='train')
plt.plot(history.history['val_loss'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have your model and test_generator already defined

# Generate predictions
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)

# Get true labels
y_true = test_generator.classes

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# Print classification report
class_names = list(test_generator.class_indices.keys())
print(classification_report(y_true, y_pred_classes, target_names=class_names))

# If you want to save the confusion matrix plot
plt.savefig('confusion_matrix.png')
print("Confusion matrix saved as 'confusion_matrix.png'")

# If you want to save the classification report to a file
with open('classification_report.txt', 'w') as f:
    f.write(classification_report(y_true, y_pred_classes, target_names=class_names))
print("Classification report saved as 'classification_report.txt'")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 218ms/step
#                 precision    recall  f1-score   support
#
#           Mild       0.26      0.70      0.38        70
#       Moderate       0.30      0.09      0.13        70
#          No_DR       0.40      0.03      0.05        70
# Proliferate_DR       0.36      0.56      0.44        70
#         Severe       0.21      0.09      0.12        70
#
#       accuracy                           0.29       350
#      macro avg       0.31      0.29      0.23       350
#   weighted avg       0.31      0.29      0.23       350
#
# Confusion matrix saved as 'confusion_matrix.png'
# Classification report saved as 'classification_report.txt'
